# %% [markdown]
# <a href="https://colab.research.google.com/github/JAYANTH1774/REINFORCEMENT-LEARNING-2303A51774/blob/main/RL_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
import numpy as np


def random_agent(environment_name, number_of_episodes=10):

    print("\n========================================")
    print("Environment:", environment_name)
    print("========================================")

    env = gym.make(environment_name)

    rewards = []

    for episode in range(number_of_episodes):

        # Reset the environment
        state, info = env.reset()

        total_reward = 0
        terminated = False
        truncated = False

        # Run the episode
        while not (terminated or truncated):

            # Select a random action
            action = env.action_space.sample()

            # Execute the action
            next_state, reward, terminated, truncated, info = env.step(action)

            # Add reward
            total_reward += reward

            # Update state
            state = next_state

        rewards.append(total_reward)

        print(
            "Episode:", episode + 1,
            "Total Reward:", total_reward
        )

    env.close()

    # Calculate results
    average_reward = np.mean(rewards)

    print("\n----------- RESULTS -----------")
    print("Total Episodes :", number_of_episodes)
    print("Rewards        :", rewards)
    print("Average Reward :", average_reward)
    print("Maximum Reward :", max(rewards))
    print("Minimum Reward :", min(rewards))


# =====================================================
# CARTPOLE
# =====================================================

print("\n\n********** CARTPOLE **********")

random_agent("CartPole-v1", 10)


# =====================================================
# MOUNTAIN CAR
# =====================================================

print("\n\n********** MOUNTAIN CAR **********")

random_agent("MountainCar-v0", 10)


# =====================================================
# FROZEN LAKE
# =====================================================

print("\n\n********** FROZEN LAKE **********")

random_agent("FrozenLake-v1", 10)
# Out:
# ********** CARTPOLE **********
#
# ...
# Environment: CartPole-v1
# ...
# Episode: 1 Total Reward: 16.0
# Episode: 2 Total Reward: 15.0
# Episode: 3 Total Reward: 23.0
# Episode: 4 Total Reward: 71.0
# Episode: 5 Total Reward: 20.0
# Episode: 6 Total Reward: 18.0
# Episode: 7 Total Reward: 17.0
# Episode: 8 Total Reward: 14.0
# Episode: 9 Total Reward: 25.0
# Episode: 10 Total Reward: 23.0
#
# ----------- RESULTS -----------
# Total Episodes : 10
# Rewards        : [16.0, 15.0, 23.0, 71.0, 20.0, 18.0, 17.0, 14.0, 25.0, 23.0]
# Average Reward : 24.2
# Maximum Reward : 71.0
# Minimum Reward : 14.0
#
#
# ********** MOUNTAIN CAR **********
#
# ...
# Environment: MountainCar-v0
# ...
# Episode: 1 Total Reward: -200.0
# Episode: 2 Total Reward: -200.0
# Episode: 3 Total Reward: -200.0
# Episode: 4 Total Reward: -200.0
# Episode: 5 Total Reward: -200.0
# Episode: 6 Total Reward: -200.0
# Episode: 7 Total Reward: -200.0
# Episode: 8 Total Reward: -200.0
# Episode: 9 Total Reward: -200.0
# ...
